# %% [markdown]
# <a href="https://colab.research.google.com/github/dinasoffa/Numerical-Optimization/blob/main/Newton'sMethod_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Newton's Method Optimization
# ### Single Variable
# - Implement the <b>Gradient decent and Newton's method</b> as a function and find the minimum of the following function:
#     - $𝒇(𝒙)=𝒙^𝟐−𝟏𝟓𝒙+𝟏$,
#
# ##### The function will return the solution and the gradient.

# %% [markdown]
# # import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from math import sqrt 
from sympy import *
from sympy.plotting import plot3d

# %%
X = np.linspace(-50,65)
X
# Out:
# array([-50.        , -47.65306122, -45.30612245, -42.95918367,
#        -40.6122449 , -38.26530612, -35.91836735, -33.57142857,
#        -31.2244898 , -28.87755102, -26.53061224, -24.18367347,
#        -21.83673469, -19.48979592, -17.14285714, -14.79591837,
#        -12.44897959, -10.10204082,  -7.75510204,  -5.40816327,
#         -3.06122449,  -0.71428571,   1.63265306,   3.97959184,
#          6.32653061,   8.67346939,  11.02040816,  13.36734694,
#         15.71428571,  18.06122449,  20.40816327,  22.75510204,
#         25.10204082,  27.44897959,  29.79591837,  32.14285714,
#         34.48979592,  36.83673469,  39.18367347,  41.53061224,
#         43.87755102,  46.2244898 ,  48.57142857,  50.91836735,
#         53.26530612,  55.6122449 ,  57.95918367,  60.30612245,
#         62.65306122,  65.        ])

# %%
f = lambda X: X**2 - 15*X +1
Df = lambda X: 2*X -15
DDf = lambda X: 2

# %%
f=(X**2) -(15*X) +1

# %%
plt.plot(X,f)
plt.show()

# %%
f_d=2*X -15

# %%
plt.plot(X,f_d)
plt.show()

# %%
f_dd=2+X*0
plt.plot(X,f_dd)
plt.show()

# %%
def G_D(x0, max_it, f ,alpha):
    x=x0
     
    for i in range(max_it):
        print(f"\n******* Iteration {i} *******")
        x=x-(alpha)*f(x)
        print(x)
        residual=np.abs(f(x))
        print(residual)
        if residual < 0.1:
            break
        
     
    
    return x,residual
 
solution,residual = G_D(40,500,Df,0.01)
# Out:
# ******* Iteration 0 *******
# 39.35
# 63.7
#
# ******* Iteration 1 *******
# 38.713
# 62.426
#
# ******* Iteration 2 *******
# 38.08874
# 61.17748
#
# ******* Iteration 3 *******
# 37.4769652
# 59.953930400000004
#
# ******* Iteration 4 *******
# 36.877425896000005
# 58.75485179200001
#
# ******* Iteration 5 *******
# 36.28987737808001
# 57.579754756160014
#
# ******* Iteration 6 *******
# 35.71407983051841
# 56.428159661036815
#
# ******* Iteration 7 *******
# 35.14979823390804
# 55.29959646781607
#
# ******* Iteration 8 *******
# 34.596802269229876
# 54.19360453845975
#
# ******* Iteration 9 *******
# 34.05486622384528
# 53.10973244769056
#
# ******* Iteration 10 *******
# 33.52376889936838
# 52.047537798736755
#
# ******* Iteration 11 *******
# 33.00329352138101
# 51.00658704276202
#
# ******* Iteration 12 *******
# 32.49322765095339
# 49.98645530190679
#
# ******* Iteration 13 *******
# 31.993363097934324
# 48.98672619586865
#
# ******* Iteration 14 *******
# 31.503495835975638
# ...

# %%
 
def newtonMethod(x0, max_it, f ,df,alpha):
    x=x0
     
    for i in range(max_it):
        print(f"\n******* Iteration {i} *******")
        x=x-(alpha)*f(x)/df(x)
        print(x)
        residual=np.abs(f(x))
        print(residual)
        if residual < 0.01:
            break
        
     
    
    return x,residual

# %%
solution,residual = newtonMethod(40,200,Df,DDf,1)
# Out:
# ******* Iteration 0 *******
# 7.5
# 0.0

# %%
solution,residual = newtonMethod(40,200,Df,DDf,0.8)
# Out:
# ******* Iteration 0 *******
# 14.0
# 13.0
#
# ******* Iteration 1 *******
# 8.8
# 2.6000000000000014
#
# ******* Iteration 2 *******
# 7.76
# 0.5199999999999996
#
# ******* Iteration 3 *******
# 7.552
# 0.1039999999999992
#
# ******* Iteration 4 *******
# 7.5104
# 0.020799999999999486
#
# ******* Iteration 5 *******
# 7.50208
# 0.004160000000000608

# %%
def newtonMethod(x0, max_it, f ,df, alpha):
    x=x0
     
    for i in range(max_it):
        print(f"\n******* Iteration {i} *******")
        x=x-(alpha)*(f(x)/df(x))
        print(x)
        residual=np.abs(f(x))
        print(residual)
        if residual < 0.1:
            break
        
     
    
    return x,residual
 
solution,residual = newtonMethod(40,200,Df,DDf,0.8)
# Out:
# ******* Iteration 0 *******
# 14.0
# 13.0
#
# ******* Iteration 1 *******
# 8.8
# 2.6000000000000014
#
# ******* Iteration 2 *******
# 7.76
# 0.5199999999999996
#
# ******* Iteration 3 *******
# 7.552
# 0.1039999999999992
#
# ******* Iteration 4 *******
# 7.5104
# 0.020799999999999486

# %% [markdown]
# ### Multi Variable
# - Implement the <b>Gradient decent and Newton's method</b> as a function and find the minimum of the following function:
#     - $𝒇(𝒙)=𝒙^𝟐+y^2$
#     - $𝒇(𝒙)=𝒙^𝟐+xy+y^2$
#     - $𝒇(𝒙)=𝒙^𝟐y$
# ##### The function will return the solution and the gradient.

# %% [markdown]
# $𝒇(𝒙)=𝒙^𝟐+y^2$

# %%
x,y = symbols('x y')
f = x**2 + y**2
plot3d(f,size=(10,7))
plt.show()

# %% [markdown]
# $𝒇(𝒙)=𝒙^𝟐+xy+y^2$

# %%
x,y = symbols('x y')
f = x**2 + x * y + y**2
plot3d(f,size=(10,7))
plt.show()

# %% [markdown]
# $𝒇(𝒙)=𝒙^𝟐y$

# %%
x,y = symbols('x y')
f = x**2 * y
plot3d(f,size=(10,7))
plt.show()

# %%
Df_1 = lambda X: np.array([2*X[0],2*X[1]])
DDf_1 = lambda X: np.array([[2,0],
                         [0,2]])

# %%
f_2 = lambda x: x**2 + x*y + y**2
Df_2 = lambda X: np.array([2*X[0]+X[1],2*X[1]+X[0]])
DDf_2 = lambda X: np.array([[2,1],
                        [1,2]])

# %%
def Gradient_Multi(x0, max_it,alpha ,epsilon, df ):
    x=x0
     
    for i in range(max_it):
        print(f"\n******* Iteration {i} *******")
        x = x -  (df(x) *alpha)
        print("x =  ",x)
        grad = np.abs(df(x))
        print("grad=",grad)
        if grad[0] < epsilon and grad[1] < epsilon:
            break
        
     
    
    return x , grad ,i

# %%
x,grad,i=Gradient_Multi((10,10),200,0.1,0.001,Df_1)
# Out:
# ******* Iteration 0 *******
# x =   [8. 8.]
# grad= [16. 16.]
#
# ******* Iteration 1 *******
# x =   [6.4 6.4]
# grad= [12.8 12.8]
#
# ******* Iteration 2 *******
# x =   [5.12 5.12]
# grad= [10.24 10.24]
#
# ******* Iteration 3 *******
# x =   [4.096 4.096]
# grad= [8.192 8.192]
#
# ******* Iteration 4 *******
# x =   [3.2768 3.2768]
# grad= [6.5536 6.5536]
#
# ******* Iteration 5 *******
# x =   [2.62144 2.62144]
# grad= [5.24288 5.24288]
#
# ******* Iteration 6 *******
# x =   [2.097152 2.097152]
# grad= [4.194304 4.194304]
#
# ******* Iteration 7 *******
# x =   [1.6777216 1.6777216]
# grad= [3.3554432 3.3554432]
#
# ******* Iteration 8 *******
# x =   [1.34217728 1.34217728]
# grad= [2.68435456 2.68435456]
#
# ******* Iteration 9 *******
# x =   [1.07374182 1.07374182]
# grad= [2.14748365 2.14748365]
#
# ******* Iteration 10 *******
# x =   [0.85899346 0.85899346]
# grad= [1.71798692 1.71798692]
#
# ******* Iteration 11 *******
# x =   [0.68719477 0.68719477]
# ...

# %%
x,grad,i=Gradient_Multi((10,10),200,0.5,0.001,Df_1)
# Out:
# ******* Iteration 0 *******
# x =   [0. 0.]
# grad= [0. 0.]

# %%
def newton_Multi(x0, max_it ,epsilon, df,DDf_1,alpha ):
    x=x0
     
    for i in range(max_it):
        print(f"\n******* Iteration {i} *******")
        x = x -  alpha*(np.linalg.inv(DDf_1(x)))*df(x)
        grad = np.abs(df(x))
        if grad[0,0] < epsilon and grad[1,1] < epsilon:
            break
        
    x_new=np.array([x[0,0],x[1,1]])
    gradient=np.array([grad[1,1],grad[1,1]])

    print(x_new)
    print(gradient)

# %%
newton_Multi((10,10),200,0.001,Df_1,DDf_1,1)
# Out:
# ******* Iteration 0 *******
# [0. 0.]
# [0. 0.]

# %%
x,grad,i=Gradient_Multi((10,10),200,0.5,0.001,Df_2)
# Out:
# ******* Iteration 0 *******
# x =   [-5. -5.]
# grad= [15. 15.]
#
# ******* Iteration 1 *******
# x =   [2.5 2.5]
# grad= [7.5 7.5]
#
# ******* Iteration 2 *******
# x =   [-1.25 -1.25]
# grad= [3.75 3.75]
#
# ******* Iteration 3 *******
# x =   [0.625 0.625]
# grad= [1.875 1.875]
#
# ******* Iteration 4 *******
# x =   [-0.3125 -0.3125]
# grad= [0.9375 0.9375]
#
# ******* Iteration 5 *******
# x =   [0.15625 0.15625]
# grad= [0.46875 0.46875]
#
# ******* Iteration 6 *******
# x =   [-0.078125 -0.078125]
# grad= [0.234375 0.234375]
#
# ******* Iteration 7 *******
# x =   [0.0390625 0.0390625]
# grad= [0.1171875 0.1171875]
#
# ******* Iteration 8 *******
# x =   [-0.01953125 -0.01953125]
# grad= [0.05859375 0.05859375]
#
# ******* Iteration 9 *******
# x =   [0.00976562 0.00976562]
# grad= [0.02929688 0.02929688]
#
# ******* Iteration 10 *******
# x =   [-0.00488281 -0.00488281]
# grad= [0.01464844 0.01464844]
#
# ******* Iteration 11 *******
# x =   [0.00244141 0.00244141]
# ...

# %%
newton_Multi((10,10),200,0.001,Df_1,DDf_1,1)
# Out:
# ******* Iteration 0 *******
# [0. 0.]
# [0. 0.]

# %%
newton_Multi((10,10),200,0.001,Df_1,DDf_1,0.9)
# Out:
# ******* Iteration 0 *******
#
# ******* Iteration 1 *******
#
# ******* Iteration 2 *******
#
# ******* Iteration 3 *******
#
# ******* Iteration 4 *******
# [1.e-04 1.e-04]
# [0.0002 0.0002]

# %%
f_5 = lambda x: x**2 * y
Df_5 = lambda X: np.array([2*X[0]*X[1],
                           X[0]**2])
DDf_5 = lambda X: np.array([[2*X[1],2*X[0]],
                         [2*X[0],0]])

# %%
newton_Multi((10,10),200,0.001,Df_1,DDf_1,0.9)
# Out:
# ******* Iteration 0 *******
#
# ******* Iteration 1 *******
#
# ******* Iteration 2 *******
#
# ******* Iteration 3 *******
#
# ******* Iteration 4 *******
# [1.e-04 1.e-04]
# [0.0002 0.0002]
